# %%
import pandas as pd
import numpy as np
dataframe = pd.read_csv('House.csv')

dataframe
# Out:
#      Unnamed: 0                   Description  \
# 0             0      5 BEDROOM HOUSE FOR RENT
# 1             1      4 BEDROOM HOUSE FOR RENT
# 2             2      4 BEDROOM HOUSE FOR RENT
# 3             3      2 BEDROOM HOUSE FOR RENT
# 4             4  COMMERCIAL PROPERTY FOR RENT
# ..          ...                           ...
# 445         445      4 BEDROOM HOUSE FOR RENT
# 446         446      4 BEDROOM HOUSE FOR RENT
# 447         447      3 BEDROOM HOUSE FOR RENT
# 448         448      4 BEDROOM HOUSE FOR RENT
# 449         449      4 BEDROOM HOUSE FOR RENT
#
#                                      House_Type  \
# 0                5 Bedroom Semi Detached Duplex
# 1                      4 Bedroom Terrace Duplex
# 2            Serviced 4 Bedroom Terraced Duplex
# 3                           2 Bedroom Apartment
# 4                           1 Room Office Space
# ..                                          ...
# 445      4 Bedroom Semi Detached Duplex With Bq
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   450 non-null    int64
#  1   Description  450 non-null    object
#  2   House_Type   450 non-null    object
#  3   Location     450 non-null    object
#  4   Price        450 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 17.7+ KB
