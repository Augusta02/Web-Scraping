# %%
import pandas as pd
import numpy as np
dataframe = pd.read_csv('dca_house_webscraping.csv')

dataframe
# Out:
#                                   Description  \
# 0     4 bedroom semi-detached duplex for rent
# 1     4 bedroom semi-detached duplex for rent
# 2          4 bedroom terraced duplex for rent
# 3          3 bedroom terraced duplex for rent
# 4   2 bedroom semi-detached bungalow for rent
# ..                                        ...
# 75         4 bedroom detached duplex for rent
# 76         4 bedroom terraced duplex for rent
# 77         4 bedroom terraced duplex for rent
# 78         2 bedroom terraced duplex for rent
# 79         2 bedroom terraced duplex for rent
#
#                                                  Type  \
# 0                   Four Bedroom Semi Detached Duplex
# 1   Tastefully Finished 4 Bedroom Semi Detached Du...
# 2      Luxury Serviced 4 Bedroom Semi Detached Duplex
# 3                              Luxury 4 Bedroom House
# 4   Newly Built Two Bedroom Flats (just Two Flats/...
# ..                                                ...
# ...

# %%
dataframe.isna().sum()
# Out:
# Description    0
# Type           0
# Location       0
# Price          0
# dtype: int64
